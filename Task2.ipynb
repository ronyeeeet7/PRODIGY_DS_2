# %% [markdown]
#  Google Colab Script for Titanic EDA

# %% [markdown]
# Google Colab-Ready EDA Code

# %%
# Step 1: Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Step 2: Load the sample Titanic dataset
df = pd.read_csv('sample_titanic_data.csv')  # Already downloaded from previous step
df.head()
# Out:
#    PassengerId  Survived  Pclass         Name     Sex  Age  SibSp  Parch  \
# 0            1         0       3  Passenger_1  female    7      2      1
# 1            2         1       3  Passenger_2  female   67      3      1
# 2            3         1       1  Passenger_3    male   17      1      2
# 3            4         0       1  Passenger_4  female   33      0      1
# 4            5         0       2  Passenger_5    male   48      3      0
#
#    Ticket   Fare Embarked
# 0  T10000  77.71        C
# 1  T10001  81.24        S
# 2  T10002  81.07        C
# 3  T10003  18.21        Q
# 4  T10004  54.50        S

# %% [markdown]
# Data Cleaning

# %%
# Check for missing values
print("Missing Values:\n", df.isnull().sum())

# View datatypes
print("\nData Types:\n", df.dtypes)

# Check basic stats
print("\nSummary Statistics:\n", df.describe(include='all'))
# Out:
# Missing Values:
#  PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64
#
# Data Types:
#  PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age              int64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked        object
# dtype: object
#
# Summary Statistics:
#          PassengerId    Survived      Pclass         Name     Sex         Age  \
# count    100.000000  100.000000  100.000000          100     100  100.000000
# unique          NaN         NaN         NaN          100       2         NaN
# top             NaN         NaN         NaN  Passenger_1  female         NaN
# freq            NaN         NaN         NaN            1      57         NaN
# mean      50.500000    0.370000    1.970000          NaN     NaN   39.170000
# std       29.011492    0.485237    0.834302          NaN     NaN   19.943382
# min        1.000000    0.000000    1.000000          NaN     NaN    2.000000
# 25%       25.750000    0.000000    1.000000          NaN     NaN   23.750000
# 50%       50.500000    0.000000    2.000000          NaN     NaN   40.500000
# 75%       75.250000    1.000000    3.000000          NaN     NaN   58.000000
# max      100.000000    1.000000    3.000000          NaN     NaN   76.000000
#
#              SibSp       Parch  Ticket        Fare Embarked
# count   100.000000  100.000000     100  100.000000      100
# unique         NaN         NaN     100         NaN        3
# top            NaN         NaN  T10000         NaN        C
# freq           NaN         NaN       1         NaN       35
# mean      1.440000    0.870000     NaN   57.859400      NaN
# std       1.131014    0.860526     NaN   28.861541      NaN
# min       0.000000    0.000000     NaN   11.020000      NaN
# 25%       0.000000    0.000000     NaN   33.750000      NaN
# 50%       1.000000    1.000000     NaN   60.055000      NaN
# 75%       2.250000    2.000000     NaN   83.172500      NaN
# max       3.000000    2.000000     NaN   99.370000      NaN

# %% [markdown]
# Exploratory Data Analysis (EDA)

# %%
sns.countplot(x='Survived', data=df)
plt.title("Survival Count")
plt.xlabel("Survived (1 = Yes, 0 = No)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Gender vs Survival

# %%
sns.countplot(x='Survived', hue='Sex', data=df)
plt.title("Survival by Gender")
plt.xlabel("Survived")
plt.ylabel("Count")
plt.legend(title='Sex')
plt.show()

# %% [markdown]
# Pclass vs Survival

# %%
sns.countplot(x='Survived', hue='Pclass', data=df)
plt.title("Survival by Passenger Class")
plt.xlabel("Survived")
plt.ylabel("Count")
plt.legend(title='Pclass')
plt.show()

# %% [markdown]
# Age Distribution

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['Age'], bins=20, kde=True)
plt.title("Age Distribution of Passengers")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Age vs Survival

# %%
plt.figure(figsize=(10, 5))
sns.violinplot(x='Survived', y='Age', data=df)
plt.title("Age vs Survival")
plt.xlabel("Survived")
plt.ylabel("Age")
plt.show()

# %% [markdown]
# Correlation Heatmap

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()
